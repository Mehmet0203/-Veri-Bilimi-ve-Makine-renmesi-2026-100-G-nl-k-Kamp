# %%
import pandas as pd

# %%
import numpy as np

# %%
data = np.random.randn(4,3)

# %%
data
# Out:
# array([[-0.21322817,  0.05068486, -0.80992808],
#        [-0.32968206,  0.55346776, -0.96450958],
#        [ 1.26232278,  1.03425114,  0.87505786],
#        [-0.06212774,  0.75160796,  0.66413303]])

# %%
data_frame = pd.DataFrame(data)

# %%
# data_frame = pd.Series(data) data_frame is not one dimensional but series

# %%
data_frame
# Out:
#           0         1         2
# 0 -0.213228  0.050685 -0.809928
# 1 -0.329682  0.553468 -0.964510
# 2  1.262323  1.034251  0.875058
# 3 -0.062128  0.751608  0.664133

# %%
type(data_frame)
# Out:
# pandas.DataFrame

# %%
type(data_frame[0]) # when we make it one dimensional it became series
# Out:
# pandas.Series

# %%
new_df = pd.DataFrame(data,index=["Atil","Zeynep","Atlas","Mehmet"],columns= ["Salary","Age","Seniority"])

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.213228  0.050685  -0.809928
# Zeynep -0.329682  0.553468  -0.964510
# Atlas   1.262323  1.034251   0.875058
# Mehmet -0.062128  0.751608   0.664133

# %%
new_df["Age"]
# Out:
# Atil      0.050685
# Zeynep    0.553468
# Atlas     1.034251
# Mehmet    0.751608
# Name: Age, dtype: float64

# %%
# new_df["Atil"] we can use columns to access data

# %%
new_df["Salary"]
# Out:
# Atil     -0.213228
# Zeynep   -0.329682
# Atlas     1.262323
# Mehmet   -0.062128
# Name: Salary, dtype: float64

# %%
new_df[["Age","Salary"]]
# Out:
#              Age    Salary
# Atil    0.050685 -0.213228
# Zeynep  0.553468 -0.329682
# Atlas   1.034251  1.262323
# Mehmet  0.751608 -0.062128

# %%
# if we want to access data by using rows we can use 
new_df.loc["Atil"]
# Out:
# Salary      -0.213228
# Age          0.050685
# Seniority   -0.809928
# Name: Atil, dtype: float64

# %%
new_df.iloc[0] # by using index and location
# Out:
# Salary      -0.213228
# Age          0.050685
# Seniority   -0.809928
# Name: Atil, dtype: float64

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.213228  0.050685  -0.809928
# Zeynep -0.329682  0.553468  -0.964510
# Atlas   1.262323  1.034251   0.875058
# Mehmet -0.062128  0.751608   0.664133

# %%
new_df.iloc[:,0] # means select all rows and bring column by using index
# Out:
# Atil     -0.213228
# Zeynep   -0.329682
# Atlas     1.262323
# Mehmet   -0.062128
# Name: Salary, dtype: float64

# %%
# data manipulation

# %%
new_df["Age"]
# Out:
# Atil      0.050685
# Zeynep    0.553468
# Atlas     1.034251
# Mehmet    0.751608
# Name: Age, dtype: float64

# %%
# new_df["Extra"] there is no column like this one

# %%
new_df["Extra"] = 10 # it will assgin 10 to the all rows

# %%
new_df
# Out:
#           Salary       Age  Seniority  Extra
# Atil   -0.213228  0.050685  -0.809928     10
# Zeynep -0.329682  0.553468  -0.964510     10
# Atlas   1.262323  1.034251   0.875058     10
# Mehmet -0.062128  0.751608   0.664133     10

# %%
new_df.drop("Extra", axis=1) # we have to indicate axis
# Out:
#           Salary       Age  Seniority
# Atil   -0.213228  0.050685  -0.809928
# Zeynep -0.329682  0.553468  -0.964510
# Atlas   1.262323  1.034251   0.875058
# Mehmet -0.062128  0.751608   0.664133

# %%
new_df.loc["Ali"] = 55

# %%
new_df # to add a new row
# Out:
#            Salary        Age  Seniority  Extra
# Atil    -0.213228   0.050685  -0.809928     10
# Zeynep  -0.329682   0.553468  -0.964510     10
# Atlas    1.262323   1.034251   0.875058     10
# Mehmet  -0.062128   0.751608   0.664133     10
# Ali     55.000000  55.000000  55.000000     55

# %%
new_df["Ali"]= 33

# %%
new_df
# Out:
#            Salary        Age  Seniority  Extra  Ali
# Atil    -0.213228   0.050685  -0.809928     10   33
# Zeynep  -0.329682   0.553468  -0.964510     10   33
# Atlas    1.262323   1.034251   0.875058     10   33
# Mehmet  -0.062128   0.751608   0.664133     10   33
# Ali     55.000000  55.000000  55.000000     55   33

# %%
# now I want to delete Ali but whic one row or column that's why axis is important

# %%
new_df.drop("Ali", axis=1)
# Out:
#            Salary        Age  Seniority  Extra
# Atil    -0.213228   0.050685  -0.809928     10
# Zeynep  -0.329682   0.553468  -0.964510     10
# Atlas    1.262323   1.034251   0.875058     10
# Mehmet  -0.062128   0.751608   0.664133     10
# Ali     55.000000  55.000000  55.000000     55

# %%
new_df.drop("Ali", axis=0)
# Out:
#           Salary       Age  Seniority  Extra  Ali
# Atil   -0.213228  0.050685  -0.809928     10   33
# Zeynep -0.329682  0.553468  -0.964510     10   33
# Atlas   1.262323  1.034251   0.875058     10   33
# Mehmet -0.062128  0.751608   0.664133     10   33

# %%
new_df # as you can see we could not delete to do this we can use inplace = True
# Out:
#            Salary        Age  Seniority  Extra  Ali
# Atil    -0.213228   0.050685  -0.809928     10   33
# Zeynep  -0.329682   0.553468  -0.964510     10   33
# Atlas    1.262323   1.034251   0.875058     10   33
# Mehmet  -0.062128   0.751608   0.664133     10   33
# Ali     55.000000  55.000000  55.000000     55   33

# %%
new_df.drop("Ali",axis = 0, inplace = True)

# %%
new_df.drop("Ali",axis = 1, inplace = True)

# %%
new_df.drop("Extra",axis = 1, inplace = True)

# %%
new_df
# Out:
#           Salary       Age  Seniority
# Atil   -0.213228  0.050685  -0.809928
# Zeynep -0.329682  0.553468  -0.964510
# Atlas   1.262323  1.034251   0.875058
# Mehmet -0.062128  0.751608   0.664133

# %%
# we can use inplace almost in every  function

# %%
new_df.loc["Atlas"]
# Out:
# Salary       1.262323
# Age          1.034251
# Seniority    0.875058
# Name: Atlas, dtype: float64

# %%
new_df.loc["Atlas"]["Salary"] # we can take intersection of a row and column
# Out:
# np.float64(1.262322781392654)

# %%
new_df.loc["Atlas","Salary"] = 100 # we can take intersection and we can change it

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil     -0.213228  0.050685  -0.809928
# Zeynep   -0.329682  0.553468  -0.964510
# Atlas   100.000000  1.034251   0.875058
# Mehmet   -0.062128  0.751608   0.664133

# %%
new_df >0
# Out:
#         Salary   Age  Seniority
# Atil     False  True      False
# Zeynep   False  True      False
# Atlas     True  True       True
# Mehmet   False  True       True

# %%
boolean_frame = new_df>0
new_df[boolean_frame]
# Out:
#         Salary       Age  Seniority
# Atil       NaN  0.050685        NaN
# Zeynep     NaN  0.553468        NaN
# Atlas    100.0  1.034251   0.875058
# Mehmet     NaN  0.751608   0.664133

# %%
new_df[new_df["Salary"]>1]
# Out:
#        Salary       Age  Seniority
# Atlas   100.0  1.034251   0.875058

# %%
new_df
# Out:
#             Salary       Age  Seniority
# Atil     -0.213228  0.050685  -0.809928
# Zeynep   -0.329682  0.553468  -0.964510
# Atlas   100.000000  1.034251   0.875058
# Mehmet   -0.062128  0.751608   0.664133

# %%
new_df.reset_index()
# Out:
#     index      Salary       Age  Seniority
# 0    Atil   -0.213228  0.050685  -0.809928
# 1  Zeynep   -0.329682  0.553468  -0.964510
# 2   Atlas  100.000000  1.034251   0.875058
# 3  Mehmet   -0.062128  0.751608   0.664133

# %%
reset_frame = new_df.reset_index() # to add new indexes

# %%
reset_frame
# Out:
#     index      Salary       Age  Seniority
# 0    Atil   -0.213228  0.050685  -0.809928
# 1  Zeynep   -0.329682  0.553468  -0.964510
# 2   Atlas  100.000000  1.034251   0.875058
# 3  Mehmet   -0.062128  0.751608   0.664133

# %%
reset_frame.loc[0]
# Out:
# index            Atil
# Salary      -0.213228
# Age          0.050685
# Seniority   -0.809928
# Name: 0, dtype: object

# %%
new_indices = ["Ati","Zey","Atl","Memo"]

# %%
new_df["NewIndex"] = new_indices

# %%
new_df
# Out:
#             Salary       Age  Seniority NewIndex
# Atil     -0.213228  0.050685  -0.809928      Ati
# Zeynep   -0.329682  0.553468  -0.964510      Zey
# Atlas   100.000000  1.034251   0.875058      Atl
# Mehmet   -0.062128  0.751608   0.664133     Memo

# %%
new_df.set_index("NewIndex",inplace=True)

# %%
new_df
# Out:
#               Salary       Age  Seniority
# NewIndex
# Ati        -0.213228  0.050685  -0.809928
# Zey        -0.329682  0.553468  -0.964510
# Atl       100.000000  1.034251   0.875058
# Memo       -0.062128  0.751608   0.664133

# %%
new_df.loc["Ati"]
# Out:
# Salary      -0.213228
# Age          0.050685
# Seniority   -0.809928
# Name: Ati, dtype: float64

# %%
# multi index

# %%
first_index = ["Simpson","Simpson","Simpson","South Park","South Park","South Park"]

# %%
inner_index = ["Homer","Bart","Marge","Cartman","Kenny","Kyle"]

# %%
zipped_index = list(zip(first_index,inner_index))

# %%
zipped_index
# Out:
# [('Simpson', 'Homer'),
#  ('Simpson', 'Bart'),
#  ('Simpson', 'Marge'),
#  ('South Park', 'Cartman'),
#  ('South Park', 'Kenny'),
#  ('South Park', 'Kyle')]

# %%
zipped_index = pd.MultiIndex.from_tuples(zipped_index)

# %%
zipped_index
# Out:
# MultiIndex([(   'Simpson',   'Homer'),
#             (   'Simpson',    'Bart'),
#             (   'Simpson',   'Marge'),
#             ('South Park', 'Cartman'),
#             ('South Park',   'Kenny'),
#             ('South Park',    'Kyle')],
#            )

# %%
sample_values = np.ones((6,2))

# %%
big_df = pd.DataFrame(sample_values,index=zipped_index,columns=["Age","Salary"])

# %%
big_df
# Out:
#                     Age  Salary
# Simpson    Homer    1.0     1.0
#            Bart     1.0     1.0
#            Marge    1.0     1.0
# South Park Cartman  1.0     1.0
#            Kenny    1.0     1.0
#            Kyle     1.0     1.0

# %%
big_df["Age"]
# Out:
# Simpson     Homer      1.0
#             Bart       1.0
#             Marge      1.0
# South Park  Cartman    1.0
#             Kenny      1.0
#             Kyle       1.0
# Name: Age, dtype: float64

# %%
# big_df.loc["Simpson"]["Homer"] this one is wrong to access inner index
big_df.loc["Simpson"].loc["Homer"]
# Out:
# Age       1.0
# Salary    1.0
# Name: Homer, dtype: float64
