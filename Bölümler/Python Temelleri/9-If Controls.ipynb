# %%
x = 5
y = 2

# %%
x > y # bigger than
# Out:
# True

# %%
x < y # less than
# Out:
# False

# %%
y = 5

# %%
x == y # equal
# Out:
# True

# %%
x >= #y bigger than or equal to
# Out:
# True

# %%
x <= y # less than or equal to
# Out:
# True

# %%
x >= 5.0
# Out:
# True

# %%
x >= 5.000001
# Out:
# False

# %%
x != y # not equal
# Out:
# False

# %%
2 > 1 and 3 > 2  # if both are ture , result is true.
# Out:
# True

# %%
1 < 2 or 3 <2 # if one is true then result is true.
# Out:
# True

# %%
not 1 == 1
# Out:
# False

# %%
10 in [10,20,30] # this method is good
# Out:
# True

# %%
10 in {10,20,30}
# Out:
# True

# %%
my_dictionary = {"a":10,"b":20,"c":30}

# %%
10 in my_dictionary
# Out:
# False

# %%
10 in my_dictionary.values()
# Out:
# True

# %%
"b" in my_dictionary
# Out:
# True

# %%
my_tuple = (10,20,30)

# %%
10 in my_tuple
# Out:
# True

# %%
my_superhero = "Batman"

# %%
my_superhero == "Batman"
# Out:
# True

# %%
my_superhero == "Superwoman"
# Out:
# False

# %%
if my_superhero =="Batman": # It only works when it is true.
    # breaking a tab is known as indentation
    print("My super hero is Batman")
# we can quit from control by pressing back space key.
print ("Not included ")
# Out:
# My super hero is Batman
# Not included

# %%
my_superhero = input("Enter your superhero")
# Out:
# Enter your superhero SuperElefantMan

# %%
if my_superhero == "Superman":
    print("Superman")
elif my_superhero == "Batman":
    print("Batman")
elif my_superhero == "Aquaman":
    print("Aquaman")
else:
    print(" :(")

# don't forget to put semicolons behind statements
# Out:
#  :(

# %%
my_age = 100

# %%
if my_age <= 18:
    print("aage <= 18")
elif my_age > 18 and my_age <= 30:
    print("18 - age - 30")
else:
    print("age > 30")
# Out:
# age > 30

# %%
my_superhero_list = ["Spider Man", "Iron Man", "Thor", "Black Widow"]

# %%
 my_superhero = "Spider Man"

# %%
if my_superhero in my_superhero_list:
    print(":)")
else:
    print(":(")
# Out:
# :)
