# %% [markdown]
# It is a data structure not type. Since it keeps more than one data .

# %%
myString = "Hello python"

# %%
myString.split()
# Out:
# ['Hello', 'python']

# %%
type(myString.split())
# Out:
# list

# %%
# List

# %%
myString
# Out:
# 'Hello python'

# %%
# We can not change one character by assigning.
#myString[0] = "a"
# This is known immutability

# %%
# But we can change lists.

# %%
myList = [10,20,30]

# %%
myList
# Out:
# [10, 20, 30]

# %%
myList[0]
# Out:
# 10

# %%
myList[0] = 50

# %%
myList[0] # as you can see it changed. It is mutable
# Out:
# 50

# %%
type(myList[0])
# Out:
# int

# %%
type(myList)
# Out:
# list

# %%
myList = [10,20,30,40,50,60,70]

# %%
len(myList)
# Out:
# 7

# %%
myList[len(myList) - 1]
# Out:
# 70

# %%
myList[ -1 ]
# Out:
# 70

# %%
myList.append(80) # it adds value within the paranthesis to to the end.

# %%
myList
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
myList.count(20)
# Out:
# 1

# %%
myList.count(25)
# Out:
# 0

# %%
myList.index(40)
# Out:
# 3

# %%
help(myList.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
myList.insert(2,35) # adding 35 to the 2. index.

# %%
myList
# Out:
# [10, 20, 35, 30, 40, 50, 60, 70, 80, 2]

# %%
myList.pop() # removes last element .
# Out:
# 2

# %%
myList
# Out:
# [10, 20, 35, 30, 40, 50, 60, 70, 80]

# %%
myList.reverse()

# %%
myList
# Out:
# [80, 70, 60, 50, 40, 30, 35, 20, 10]

# %%
myList.sort()

# %%
myList
# Out:
# [10, 20, 30, 35, 40, 50, 60, 70, 80]

# %%
x = input("We can write here messages")
# Out:
# We can write here messages 5555555555

# %%
type(x) # values came from input are strings.
# Out:
# str

# %%
x = input("Enter x :")
# Out:
# Enter x : 10

# %%
y = input("Enter y :")
# Out:
# Enter y : 20

# %%
z = input("Enter z :")
# Out:
# Enter z : 30

# %%
inputList = []

# %%
type(inputList)
# Out:
# list

# %%
len(inputList)
# Out:
# 0

# %%
inputList.append(x)
inputList.append(y)
inputList.append(z)

# %%
inputList
# Out:
# ['10', '20', '30', '10', '20', '30', '10', '20', '30', '10', '20', '30']

# %%
inputList[1]
# Out:
# '20'

# %%
inputList[1] * 2 # Is it interesting ?
# Out:
# '2020'

# %%
type(inputList[1] )
# Out:
# str

# %%
int(inputList[1]) * 2
# Out:
# 40

# %% [markdown]
# Type converting

# %%
myString = "40"

# %%
int(myString)
# Out:
# 40

# %%
float(myString)
# Out:
# 40.0

# %%
myString = "Python"

# %%
# int(myString) since this is not logical we could not.

# %%
str(inputList) # to convert into string
# Out:
# "['10', '20', '30', '10', '20', '30', '10', '20', '30', '10', '20', '30']"

# %%
mixedList = ["Nemo",100,3.15]

# %%
type(mixedList)
# Out:
# list

# %%
list1 = [10,20,30]
list2 = [40,50,60]

# %%
list1 + list2
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
list1 * 2
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#list1/5 we can not divide.

# %%
type(mixedList[0])
# Out:
# str

# %%
type(mixedList[1])
# Out:
# int

# %%
type(mixedList[2])
# Out:
# float

# %%
#nestedlist

# %%
myNestedList = [10,20,3.15,"Nemo",[1,2,3]]

# %%
myNestedList[0]
# Out:
# 10

# %%
myNestedList[1]
# Out:
# 20

# %%
myNestedList[2]
# Out:
# 3.15

# %%
myNestedList[3]
# Out:
# 'Nemo'

# %%
myNestedList[4]
# Out:
# [1, 2, 3]

# %%
smallList = myNestedList[4]

# %%
smallList
# Out:
# [1, 2, 3]

# %%
type(smallList)
# Out:
# list

# %%
myNestedList[4][1] # to acces element of list that is inside another list.
# Out:
# 2

# %%
lastList = ["a","b",["c","d","e"],"f"]

# %%
len(lastList)
# Out:
# 4

# %%
lastList[2][1]
# Out:
# 'd'

# %%
#slicing operations are valid here too.

# %%
myList
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
myList[::]
# Out:
# [10, 20, 30, 40, 50, 60, 70]

# %%
myList[::2]
# Out:
# [10, 30, 50, 70]
