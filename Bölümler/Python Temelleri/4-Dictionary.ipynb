# %%
# they are Key - Value pairing.

# %%
fruit_list = ["banana","apple"]

# %%
calorie_list = [100,150]

# %%
fruit_list[0]
# Out:
# 'banana'

# %%
calorie_list[0]
# Out:
# 100

# %%
fitness_dictionary = {"banana":100,"apple":150}

# %%
type(fitness_dictionary)
# Out:
# dict

# %%
fitness_dictionary["banana"]
# Out:
# 100

# %%
fitness_dictionary["apple"]
# Out:
# 150

# %%
fitness_dictionary.keys() # to learn keys
# Out:
# dict_keys(['banana', 'apple'])

# %%
fitness_dictionary.values()
# Out:
# dict_values([100, 150])

# %%
type(fitness_dictionary.values())
# Out:
# dict_values

# %%
list(fitness_dictionary.values()) # to turn into list
# Out:
# [100, 150]

# %%
fitness_dictionary["banana"] = 200 # it is mutable

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150}

# %%
fitness_dictionary["melon"] = 300 # we can add new key-value pairs.

# %%
fitness_dictionary
# Out:
# {'banana': 200, 'apple': 150, 'melon': 300}

# %%
fitness_dictionary["appl"] # aplying non exist key
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 fitness_dictionary["appl"] # aplying non exist key
#
# KeyError: 'appl'

# %%
help(fitness_dictionary.get) # by using this we can prevent applications from crashing
# Out:
# Help on built-in function get:
#
# get(key, default=None, /) method of builtins.dict instance
#     Return the value for key if key is in the dictionary, else default.

# %%
# just write a part of variable then click to the tab digit it will complete variable. To gain speed.

# %%
fitness_dictionary.get("apple",0) # if apple was not exist then it would give us 0.
# Out:
# 150

# %%
my_dictionary = {100:"a",200:"b",300:"c"}

# %%
my_dictionary[100]
# Out:
# 'a'

# %%
my_dictionary = {"key1":"value1","key2":"value2","key3":"value3"}

# %%
my_dictionary["key1"]
# Out:
# 'value1'

# %%
my_mixed_dictionary = {"key1":100,"key2":3.14,"key3":[10,20,30]}

# %%
my_mixed_dictionary["key1"]
# Out:
# 100

# %%
my_mixed_dictionary["key3"][1]
# Out:
# 20

# %%
last_dictionary = {"k1":10,"k2":[10,20,30,40,50],"k3":"string","k4":{"a":100,"b":200}}

# %%
last_dictionary["k4"]["a"]
# Out:
# 100
