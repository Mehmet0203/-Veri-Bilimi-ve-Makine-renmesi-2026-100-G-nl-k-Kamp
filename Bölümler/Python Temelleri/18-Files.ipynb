# %%
#create a file named myFile.txt

# %%
myFile = open("myfile.txt")

# %%
type(myFile)
# Out:
# _io.TextIOWrapper

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3'

# %%
myFile.read() # since it reads if we want to reread then we should go to starting point
# Out:
# ''

# %%
myFile.seek(0) # to go starting point
# Out:
# 0

# %%
myFile.read()
# Out:
# 'test1\ntest2\ntest3'

# %%
myFile.read()
# Out:
# ''

# %%
myFile.close()

# %%
# thanks to this below statement we will get rid of to seek or close .
with open("myfile.txt") as myFile:
    myContent = myFile.read()

# %%
myContent
# Out:
# 'test1\ntest2\ntest3'

# %%
myContent
# Out:
# 'test1\ntest2\ntest3'

# %%
with open ("myfile.txt",mode="w") as myNewFile:
    myNewFile.write("test4 \n test5")

# %%
myNewFile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='cp1254'>

# %%
with open("myfile.txt",mode="r") as myFile2:
    myContent = myFile2.read()

# %%
myContent
# Out:
# 'test4 \n test5'

# %%
# but as you can see it deleted previous text.

# %%
# to prevent we can use below one;
#w--> write, r-->read, a-->append

# %%
with open ("myfile.txt",mode="a") as myNewFile3:
    myNewFile3.write("test7")

# %%
with open("myfile.txt",mode="r") as myFile5:
    myContent = myFile5.read()

# %%
myContent
# Out:
# 'test4 \n test5test4 \n test5test4 \n test5test7'
