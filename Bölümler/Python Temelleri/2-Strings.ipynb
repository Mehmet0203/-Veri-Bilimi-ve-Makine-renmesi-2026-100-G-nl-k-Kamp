# %%
"HelLo Universe" # Strings used withing double quotation marks. We can use single as well.
# Out:
# 'HelLo Universe'

# %%
print("Hello python")
# Out:
# Hello python

# %%
name = "Nemo"

# %%
type(name)
# Out:
# str

# %%
# Using single quotation marks can cause problems like bellow one;
'Nemo's place'
# Out:
#   Cell In[7], line 2
#     'Nemo's place'
#                  ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
"Nemo's place"
# Out:
# "Nemo's place"

# %%
# we can see attributes of an variable type by typin . and pressing tab button.

# %%
name.capitalize() # used to make first character capital.
# Out:
# 'Nemo'

# %%
# if I remove paranthesis then it only says here is a function like that.
name.capitalize
# Out:
# <function str.capitalize()>

# %%
# If you don't know what a function does then you can use help.
help(name.count)
# Out:
# Help on built-in function count:
#
# count(sub[, start[, end]], /) method of builtins.str instance
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
name.count("a") # it returns number of 'a' that is inside the value.
# Out:
# 0

# %%
name.upper()
# Out:
# 'NEMO'

# %%
name # as you can see it does not changed.
# Out:
# 'Nemo'

# %%
# if we want to keep new value then we should store within a new variable.

# %%
len(name) # length
# Out:
# 4

# %%
print("Fish \n Nemo") # \n this escape character used to pass a new line.
# Out:
# Fish
#  Nemo

# %%
# Escape characters
# \n new line
# \t tab

# %% [markdown]
# Index

# %%
myString = "Hello python" # strings behave like an array

# %%
myString[4]
# Out:
# 'o'

# %%
# It is easy to access first character. What about last one ?

# %%
len(myString)
# Out:
# 12

# %%
len(myString) - 1 # it will give us last index of value.

# %%
myString[len(myString) - 1] # this one is same with myString[ -1 ]
# Out:
# 'n'

# %%
myString[ -1 ]
# Out:
# 'n'

# %%
myString[ -2 ]
# Out:
# 'o'

# %% [markdown]
# Slicing

# %%
barcode = "ABCDE123123982" # if we want to take only one part not all.

# %%
barcode[0]
# Out:
# 'A'

# %%
barcode [1]
# Out:
# 'B'

# %%
barcode [2]
# Out:
# 'C'

# %%
"A" + "B" #  we can concatenate string by adding them .
# Out:
# 'AB'

# %%
name = "Nemo"

# %%
surname = "Ergin"

# %%
fullname = name+ " " + surname

# %%
fullname
# Out:
# 'Nemo Ergin'

# %%
fullname * 5 # will write 5 times next to each other.
# Out:
# 'Nemo ErginNemo ErginNemo ErginNemo ErginNemo Ergin'

# %%
barcode[0] + barcode[1] + barcode[2] # to take first three but it is hard so we are going to use slicing
# Out:
# 'ABC'

# %%
barcode[::]
# Out:
# 'ABCDE123123982'

# %%
#barcode[starting index: stopping index: stepping size]

# %%
barcode[3::] # it starts from third index
# Out:
# 'DE123123982'

# %%
barcode[:3:] #stopping index, it does not take third index it only stops.
# Out:
# 'ABC'

# %%
# starting index is inclusive , stopping index is exclusive

# %%
barcode[::2]
# Out:
# 'ACE2138'

# %%
barcode[::3]
# Out:
# 'AD228'

# %%
barcode[3:5:]
# Out:
# 'DE'

# %%
barcode[1:9:2]
# Out:
# 'BD13'

# %%
barcode[::-1] # it will start form end. So we obtains reversed version. This is a python trick.
# Out:
# '289321321EDCBA'

# %%
name = "Nemo Ergin"

# %%
name.index("o")
# Out:
# 3

# %%
name.split()
# Out:
# ['Nemo', 'Ergin']

# %%
type(name.split())
# Out:
# list
