# %% [markdown]
# Numbers

# %%
# type is used to detect type of a variable.

# %%
type(11)
# Out:
# int

# %%
#int --> integer

# %%
type(3.14)
# Out:
# float

# %%
#float --> floating point

# %%
x = - 100
pi = 3.14

# %%
x + pi
# Out:
# -96.86

# %%
myInt = 11
myFloat = 1.33333
# myInt is bigger than myFloat but myFloat  takes more space in the memory
# That's why we are using different types. While one is integer other is floating point.

# %%
# we can use different writing style to increase readability. It is good for clean code.
# camelCase
# snake_case

# %%
40 / 4 # Dividing an integer by another integer normally gives us anathor integer, but in python it gives us floating point.
# Out:
# 10.0

# %%
type(40 / 4)
# Out:
# float

# %%
type(4)
# Out:
# int

# %%
type(4.0)
# Out:
# float

# %%
# This is only valid for division.

# %%
4 * 2 # multiplication
# Out:
# 8

# %%
4 + 2 # addition
# Out:
# 6

# %%
4 - 2 # subtraction
# Out:
# 2

# %%
# Here is an interesting point. Please look at the end of output.
4.4 - 2
# Out:
# 2.4000000000000004

# %%
# Precedence in the mathematic is valid here as well.

# %%
2 - 10 * 2
# Out:
# -18

# %%
2 * 2 * 2
2 ** 3 # exponentiation
# They are same.
# Out:
# 8

# %%
10 % 3 # remainder
# Out:
# 1
