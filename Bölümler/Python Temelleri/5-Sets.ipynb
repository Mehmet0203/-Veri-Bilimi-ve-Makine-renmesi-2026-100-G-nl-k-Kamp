# %%
#unique elements, unordered

# %%
myList = [10,20,30,40,10,20,40,10]

# %%
len(myList)
# Out:
# 8

# %%
myList
# Out:
# [10, 20, 30, 40, 10, 20, 40, 10]

# %%
mySet = set(myList)

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet = {10,20,30,40,10,20,40,10}

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(10) #We can not add 10 since it already exists.

# %%
mySet
# Out:
# {10, 20, 30, 40}

# %%
mySet.add(50)

# %%
mySet
# Out:
# {10, 20, 30, 40, 50}

# %%
#mySet[0] index is not used for sets.

# %%
mySet2 = {30,40,50,60,70}

# %%
mySet.union(mySet2)
# Out:
# {10, 20, 30, 40, 50, 60, 70}

# %%
mySet.intersection(mySet2)
# Out:
# {30, 40, 50}

# %%
countryList = ["de","fr","tr","fr","nl","tr"]

# %%
len(countryList)
# Out:
# 6

# %%
len(set(countryList))
# Out:
# 4

# %%
# to create an empty list
emptyList = []

# %%
emptyList.append(10)
emptyList.append(20)
emptyList.append(30)

# %%
emptyList
# Out:
# [10, 20, 30]

# %%
# to create an empty set. This one is a bit strange :)
emptySet = {}

# %%
type(emptySet) # it shows us as dict. what about set ?
# Out:
# dict

# %%
emptySet  = set()

# %%
type(emptySet)
# Out:
# set

# %%
len(emptySet)
# Out:
# 0

# %%
emptySet.add(10)
emptySet.add(10)
emptySet.add(10)
emptySet.add(20)
emptySet.add(30)

# %%
emptySet
# Out:
# {10, 20, 30}

# %%
# we can create empty structures as below ;
emptyList = list()
emptyDict = dict()
emptySet = set()
