# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
# it is used to control something is done or not.

# %%
5 > 3
# Out:
# True

# %%
5 == 5
# Out:
# True

# %%
age =input("Enter your age:")
# Out:
# Enter your age: 11

# %%
int(age) > 18 # remember age is a string.
# Out:
# False
